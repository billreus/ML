# %%
import numpy as np

import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

# %matplotlib inline

path = 'D:/CS/ML/Kaggle/HousePrices/all/'

train = pd.read_csv('%s%s' %(path, 'train.csv'))

test = pd.read_csv('%s%s' %(path, 'test.csv'))

# %%
# 设置表格纵轴显示数量
pd.set_option('max_columns',200)
train.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
# Id               1459 non-null int64
# MSSubClass       1459 non-null int64
# MSZoning         1455 non-null object
# LotFrontage      1232 non-null float64
# LotArea          1459 non-null int64
# Street           1459 non-null object
# Alley            107 non-null object
# LotShape         1459 non-null object
# LandContour      1459 non-null object
# Utilities        1457 non-null object
# LotConfig        1459 non-null object
# LandSlope        1459 non-null object
# Neighborhood     1459 non-null object
# Condition1       1459 non-null object
# Condition2       1459 non-null object
# BldgType         1459 non-null object
# HouseStyle       1459 non-null object
# OverallQual      1459 non-null int64
# OverallCond      1459 non-null int64
# YearBuilt        1459 non-null int64
# YearRemodAdd     1459 non-null int64
# RoofStyle        1459 non-null object
# ...

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
# 协方差（-1，1）之间

train_corr = train.drop('Id', axis=1).corr()

train_corr.head(5)
# Out:
#              MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass     1.000000    -0.386347 -0.139781     0.032628    -0.059316
# LotFrontage   -0.386347     1.000000  0.426095     0.251646    -0.059213
# LotArea       -0.139781     0.426095  1.000000     0.105806    -0.005636
# OverallQual    0.032628     0.251646  0.105806     1.000000    -0.091932
# OverallCond   -0.059316    -0.059213 -0.005636    -0.091932     1.000000
#
#              YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# MSSubClass    0.027850      0.040581    0.022936   -0.069836   -0.065649
# LotFrontage   0.123349      0.088866    0.193458    0.233633    0.049900
# LotArea       0.014228      0.013788    0.104160    0.214103    0.111170
# OverallQual   0.572323      0.550684    0.411876    0.239666   -0.059119
# OverallCond  -0.375983      0.073741   -0.128101   -0.046231    0.040229
#
#              BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# ...

# %%
# 对于价格最大的11个协方差，有价格本身所以等于10个

cols = train_corr.nlargest(11, 'SalePrice')

cols
# Out:
#               MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# SalePrice      -0.084284     0.351799  0.263843     0.790982    -0.077856
# OverallQual     0.032628     0.251646  0.105806     1.000000    -0.091932
# GrLivArea       0.074853     0.402797  0.263116     0.593007    -0.079686
# GarageCars     -0.040110     0.285691  0.154871     0.600671    -0.185758
# GarageArea     -0.098672     0.344997  0.180403     0.562022    -0.151521
# TotalBsmtSF    -0.238518     0.392075  0.260833     0.537808    -0.171098
# 1stFlrSF       -0.251758     0.457181  0.299475     0.476224    -0.144203
# FullBath        0.131608     0.198769  0.126031     0.550600    -0.194149
# TotRmsAbvGrd    0.040380     0.352096  0.190015     0.427452    -0.057583
# YearBuilt       0.027850     0.123349  0.014228     0.572323    -0.375983
# YearRemodAdd    0.040581     0.088866  0.013788     0.550684     0.073741
#
#               YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# ...

# %%
col = cols['SalePrice'].index

col
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt',
#        'YearRemodAdd'],
#       dtype='object')

# %%
# 取前十一个纵轴的矩阵

train10 = train[col].values

# 返回矩阵形式的协方差(-1,1)
corr10 = np.corrcoef(train10.T)

# %%
a = plt.subplots(figsize=(22, 12))

a = sns.heatmap(corr10, vmin=0, vmax=1 , annot=True, square=True, annot_kws={'size':10}, yticklabels=col.values, xticklabels=col.values)

# %%
# 整体材料装饰评分

plt.scatter(train['OverallQual'],train['SalePrice'])

# %%
fig = plt.figure(figsize=(25, 8))

# 地上面积

ax1 = fig.add_subplot(1,3,1)

ax1.scatter(train['GrLivArea'],train['SalePrice'])

# 地上总房间

ax2 = fig.add_subplot(1,3,2)

ax2.scatter(train['TotRmsAbvGrd'],train['SalePrice'])

ax3 = fig.add_subplot(1,3,3)

ax3.scatter(train['TotRmsAbvGrd'],train['GrLivArea'])

# %% [markdown]
# # 数据清洗

# %%
#合并测试训练集

test['SalePrice']= None

train_test = pd.concat((train, test)).reset_index(drop=True)

# train_test = pd.concat([train, test],ignore_index=True)

train_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2919 entries, 0 to 2918
# Data columns (total 81 columns):
# Id               2919 non-null int64
# MSSubClass       2919 non-null int64
# MSZoning         2915 non-null object
# LotFrontage      2433 non-null float64
# LotArea          2919 non-null int64
# Street           2919 non-null object
# Alley            198 non-null object
# LotShape         2919 non-null object
# LandContour      2919 non-null object
# Utilities        2917 non-null object
# LotConfig        2919 non-null object
# LandSlope        2919 non-null object
# Neighborhood     2919 non-null object
# Condition1       2919 non-null object
# Condition2       2919 non-null object
# BldgType         2919 non-null object
# HouseStyle       2919 non-null object
# OverallQual      2919 non-null int64
# OverallCond      2919 non-null int64
# YearBuilt        2919 non-null int64
# YearRemodAdd     2919 non-null int64
# RoofStyle        2919 non-null object
# ...

# %%
# 缺失值排序

total= train_test.isnull().sum().sort_values(ascending=False)

total[total>0]
# Out:
# PoolQC          2909
# MiscFeature     2814
# Alley           2721
# Fence           2348
# SalePrice       1459
# FireplaceQu     1420
# LotFrontage      486
# GarageQual       159
# GarageYrBlt      159
# GarageFinish     159
# GarageCond       159
# GarageType       157
# BsmtExposure      82
# BsmtCond          82
# BsmtQual          81
# BsmtFinType2      80
# BsmtFinType1      79
# MasVnrType        24
# MasVnrArea        23
# MSZoning           4
# Utilities          2
# Functional         2
# BsmtFullBath       2
# BsmtHalfBath       2
# GarageArea         1
# BsmtFinSF2         1
# Exterior1st        1
# TotalBsmtSF        1
# GarageCars         1
# BsmtUnfSF          1
# Electrical         1
# BsmtFinSF1         1
# KitchenQual        1
# SaleType           1
# Exterior2nd        1
# dtype: int64

# %%
# 缺失值做成表格

# miss = total[total>0].reset_index()

# miss.to_csv("D:\CS\miss.csv", encoding='utf-8', index=False)

# %%
# 用none填补缺失值
none_col = ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu', 
            'GarageQual', 'GarageYrBlt', 'GarageFinish', 'GarageCond',
            'GarageType', 'BsmtExposure', 'BsmtCond', 'BsmtQual', 
            'BsmtFinType2', 'BsmtFinType1', 'MasVnrType' ]
for nnone in none_col:
    train_test[nnone].fillna('None', inplace=True)

# %%
# 用0填补缺失值
zero_col = ['MasVnrArea', 'GarageArea', 'BsmtFinSF2', 'TotalBsmtSF', 'GarageCars', 'BsmtUnfSF', 'BsmtFinSF1']
for zzero in zero_col:
    train_test[zzero].fillna(0, inplace=True)

# %%
# 用众数填补缺失值
all_col = ["MSZoning", "BsmtFullBath", "BsmtHalfBath", "Utilities", "Functional", "Electrical", "KitchenQual", "SaleType","Exterior1st", "Exterior2nd"]
for aall in all_col:
    train_test[aall].fillna(train_test[aall].mode()[0], inplace=True)

# %%
total= train_test.isnull().sum().sort_values(ascending=False)

total[total>0]
# Out:
# SalePrice      1459
# LotFrontage     486
# dtype: int64

# %%
# 对LotFrontage预测

# LotFrontage与Neighborhood的关系
train_test.groupby(['Neighborhood'])[['LotFrontage']].agg(['mean','median','count'])
# Out:
#              LotFrontage
#                     mean median count
# Neighborhood
# Blmngtn        46.900000   43.0    20
# Blueste        27.300000   24.0    10
# BrDale         21.500000   21.0    30
# BrkSide        55.789474   51.0    95
# ClearCr        88.150000   80.5    20
# CollgCr        71.336364   70.0   220
# Crawfor        69.951807   70.0    83
# Edwards        66.910112   65.0   178
# Gilbert        74.207207   64.0   111
# IDOTRR         62.241379   60.0    87
# MeadowV        25.606061   21.0    33
# Mitchel        75.144444   74.0    90
# NAmes          75.210667   73.0   375
# NPkVill        28.142857   24.0    21
# NWAmes         81.517647   80.0    85
# NoRidge        91.629630   89.0    54
# NridgHt        84.184049   92.0   163
# OldTown        61.777293   60.0   229
# SWISU          59.068182   60.0    44
# Sawyer         74.551020   72.0    98
# SawyerW        70.669811   67.0   106
# Somerst        64.549383   72.5   162
# ...

# %%
# LotFrontage与LotArea的关系

train_test["LotAreaCut"] = pd.qcut(train_test.LotArea,10)

train_test.groupby(['LotAreaCut'])[['LotFrontage']].agg(['mean','median','count'])
# Out:
#                     LotFrontage
#                            mean median count
# LotAreaCut
# (1299.999, 4922.4]    35.741036   34.0   251
# (4922.4, 7007.6]      55.460674   52.0   267
# (7007.6, 7960.4]      63.008000   62.0   250
# (7960.4, 8741.0]      66.964844   65.0   256
# (8741.0, 9453.0]      70.106996   70.0   243
# (9453.0, 10151.6]     73.972656   75.0   256
# (10151.6, 11001.2]    73.650794   75.0   252
# (11001.2, 12203.8]    83.377193   82.0   228
# (12203.8, 14300.6]    84.991228   85.0   228
# (14300.6, 215245.0]   94.188119   90.0   202

# %%
# 中位数填补

train_test['LotFrontage']=train_test.groupby(['LotAreaCut', 'Neighborhood'])['LotFrontage'].transform(lambda x: x.fillna(x.median()))

# %%
# 部分无法填补使用此填补

train_test['LotFrontage']=train_test.groupby(['LotAreaCut'])['LotFrontage'].transform(lambda x: x.fillna(x.median()))

# %%
total= train_test.isnull().sum().sort_values(ascending=False)

total[total>0]
# Out:
# SalePrice    1459
# dtype: int64

# %% [markdown]
# # 特征工程

# %%
plt.scatter(train['MSSubClass'],train['SalePrice'])

# %%
# msssubclass的test中有一个150，所以用train列表有漏洞。

#train_test.groupby(['MSSubClass'])[['SalePrice']].agg(['mean','median','count'])
train.groupby(['MSSubClass'])[['SalePrice']].agg(['mean','median','count'])
# Out:
#                 SalePrice
#                      mean  median count
# MSSubClass
# 20          185224.811567  159250   536
# 30           95829.724638   99900    69
# 40          156125.000000  142500     4
# 45          108591.666667  107500    12
# 50          143302.972222  132000   144
# 60          239948.501672  215200   299
# 70          166772.416667  156000    60
# 75          192437.500000  163500    16
# 80          169736.551724  166500    58
# 85          147810.000000  140750    20
# 90          133541.076923  135980    52
# 120         200779.080460  192000    87
# 160         138647.380952  146000    63
# 180         102300.000000   88500    10
# 190         129613.333333  128250    30

# %%
# 对离散数字转换成字符型，方便使用map分类和后续get_dummies编码
NumStr = ["MSSubClass","BsmtFullBath","BsmtHalfBath","HalfBath","BedroomAbvGr","KitchenAbvGr","MoSold","YrSold","YearBuilt","YearRemodAdd","LowQualFinSF","GarageYrBlt","OverallQual","OverallCond","FullBath","Fireplaces","GarageFinish"]
for col in NumStr:
    train_test[col]=train_test[col].astype(str)

# %%
# 做标签

def map_values():
    train_test["oMSSubClass"] = train_test.MSSubClass.map({'120':1, 
                                        '70':2, '80':2, '150':2,
                                        '60':3, 
                                        '85':4, '40':4, '160':4, 
                                        '50':5, '90':5, '190':5, 
                                        '30': 6, '45':6, '180':6,
                                        '20':7, '75':7})
    
    train_test["oMSZoning"] = train_test.MSZoning.map({'C (all)':1, 'RH':2, 'RM':2, 'RL':3, 'FV':4})
    
    train_test["oNeighborhood"] = train_test.Neighborhood.map({'MeadowV':1,
                                               'IDOTRR':2, 'BrDale':2,
                                               'OldTown':3, 'Edwards':3, 'BrkSide':3,
                                               'Sawyer':4, 'Blueste':4, 'SWISU':4, 'NAmes':4,
                                               'NPkVill':5, 'Mitchel':5,
                                               'SawyerW':6, 'Gilbert':6, 'NWAmes':6,
                                               'Blmngtn':7, 'CollgCr':7, 'ClearCr':7, 'Crawfor':7,
                                               'Veenker':8, 'Somerst':8, 'Timber':8,
                                               'StoneBr':9,
                                               'NoRidge':10, 'NridgHt':10})
    
    train_test["oCondition1"] = train_test.Condition1.map({'Artery':1,
                                           'Feedr':2, 'RRAe':2,
                                           'Norm':3, 'RRAn':3,
                                           'PosN':4, 'RRNe':4,
                                           'PosA':5 ,'RRNn':5})
    
    train_test["oBldgType"] = train_test.BldgType.map({'2fmCon':1, 'Duplex':1, 'Twnhs':1, '1Fam':2, 'TwnhsE':2})
    
    train_test["oHouseStyle"] = train_test.HouseStyle.map({'1.5Unf':1, 
                                           '1.5Fin':2, '2.5Unf':2, 'SFoyer':2, 
                                           '1Story':3, 'SLvl':3,
                                           '2Story':4, '2.5Fin':4})
    
    train_test["oExterior1st"] = train_test.Exterior1st.map({'BrkComm':1,
                                             'AsphShn':2, 'CBlock':2, 'AsbShng':2,
                                             'WdShing':3, 'Wd Sdng':3, 'MetalSd':3, 'Stucco':3, 'HdBoard':3,
                                             'BrkFace':4, 'Plywood':4,
                                             'VinylSd':5,
                                             'CemntBd':6,
                                             'Stone':7, 'ImStucc':7})
    
    train_test["oMasVnrType"] = train_test.MasVnrType.map({'BrkCmn':1, 'None':1, 'BrkFace':2, 'Stone':3})
    
    train_test["oExterQual"] = train_test.ExterQual.map({'Fa':1, 'TA':2, 'Gd':3, 'Ex':4})
    
    train_test["oFoundation"] = train_test.Foundation.map({'Slab':1, 
                                           'BrkTil':2, 'CBlock':2, 'Stone':2,
                                           'Wood':3, 'PConc':4})
    
    train_test["oBsmtQual"] = train_test.BsmtQual.map({'Fa':2, 'None':1, 'TA':3, 'Gd':4, 'Ex':5})
    
    train_test["oBsmtExposure"] = train_test.BsmtExposure.map({'None':1, 'No':2, 'Av':3, 'Mn':3, 'Gd':4})
    
    train_test["oHeating"] = train_test.Heating.map({'Floor':1, 'Grav':1, 'Wall':2, 'OthW':3, 'GasW':4, 'GasA':5})
    
    train_test["oHeatingQC"] = train_test.HeatingQC.map({'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5})
    
    train_test["oKitchenQual"] = train_test.KitchenQual.map({'Fa':1, 'TA':2, 'Gd':3, 'Ex':4})
    
    train_test["oFunctional"] = train_test.Functional.map({'Maj2':1, 'Maj1':2, 'Min1':2, 'Min2':2, 'Mod':2, 'Sev':2, 'Typ':3})
    
    train_test["oFireplaceQu"] = train_test.FireplaceQu.map({'None':1, 'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5})
    
    train_test["oGarageType"] = train_test.GarageType.map({'CarPort':1, 'None':1,
                                           'Detchd':2,
                                           '2Types':3, 'Basment':3,
                                           'Attchd':4, 'BuiltIn':5})
    
    train_test["oGarageFinish"] = train_test.GarageFinish.map({'None':1, 'Unf':2, 'RFn':3, 'Fin':4})
    
    train_test["oPavedDrive"] = train_test.PavedDrive.map({'N':1, 'P':2, 'Y':3})
    
    train_test["oSaleType"] = train_test.SaleType.map({'COD':1, 'ConLD':1, 'ConLI':1, 'ConLw':1, 'Oth':1, 'WD':1,
                                       'CWD':2, 'Con':3, 'New':3})
    
    train_test["oSaleCondition"] = train_test.SaleCondition.map({'AdjLand':1, 'Abnorml':2, 'Alloca':2, 'Family':2, 'Normal':3, 'Partial':4})            
                
                        
                        
    
    return "Done!"

# %%
train.groupby(['MSZoning'])[['SalePrice']].agg(['mean','median','count'])
# Out:
#               SalePrice
#                    mean  median count
# MSZoning
# C (all)    74528.000000   74700    10
# FV        214014.061538  205950    65
# RH        131558.375000  136500    16
# RL        191004.994787  174000  1151
# RM        126316.830275  120500   218

# %%
train.groupby(['Neighborhood'])[['SalePrice']].agg(['mean','median','count'])
# Out:
#                   SalePrice
#                        mean  median count
# Neighborhood
# Blmngtn       194870.882353  191000    17
# Blueste       137500.000000  137500     2
# BrDale        104493.750000  106000    16
# BrkSide       124834.051724  124300    58
# ClearCr       212565.428571  200250    28
# CollgCr       197965.773333  197200   150
# Crawfor       210624.725490  200624    51
# Edwards       128219.700000  121750   100
# Gilbert       192854.506329  181000    79
# IDOTRR        100123.783784  103000    37
# MeadowV        98576.470588   88000    17
# Mitchel       156270.122449  153500    49
# NAmes         145847.080000  140000   225
# NPkVill       142694.444444  146000     9
# NWAmes        189050.068493  182900    73
# NoRidge       335295.317073  301500    41
# NridgHt       316270.623377  315000    77
# OldTown       128225.300885  119000   113
# SWISU         142591.360000  139500    25
# Sawyer        136793.135135  135000    74
# ...

# %%
train.groupby(['Condition1'])[['SalePrice']].agg(['mean','median','count'])
# Out:
#                 SalePrice
#                      mean  median count
# Condition1
# Artery      135091.666667  119550    48
# Feedr       142475.481481  140000    81
# Norm        184495.492063  166500  1260
# PosA        225875.000000  212500     8
# PosN        215184.210526  200000    19
# RRAe        138400.000000  142500    11
# RRAn        184396.615385  171495    26
# RRNe        190750.000000  190750     2
# RRNn        212400.000000  214000     5

# %%
train.groupby(['BldgType'])[['SalePrice']].agg(['mean','median','count'])
# Out:
#               SalePrice
#                    mean  median count
# BldgType
# 1Fam      185763.807377  167900  1220
# 2fmCon    128432.258065  127500    31
# Duplex    133541.076923  135980    52
# Twnhs     135911.627907  137500    43
# TwnhsE    181959.342105  172200   114

# %%
map_values()
# Out:
# 'Done!'

# %%
# 删除无用标签和售价
train_test.drop("LotAreaCut",axis=1,inplace=True)
train_test.drop(['SalePrice'],axis=1,inplace=True)

# %%
#暂时不用
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.preprocessing import LabelEncoder

class labelenc(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
    
    def fit(self,X,y=None):
        return self
    
    def transform(self,X):
        lab=LabelEncoder()
        X["YearBuilt"] = lab.fit_transform(X["YearBuilt"])
        X["YearRemodAdd"] = lab.fit_transform(X["YearRemodAdd"])
        X["GarageYrBlt"] = lab.fit_transform(X["GarageYrBlt"])
        return X

# %%
# 对年份进行标签编码
from sklearn.preprocessing import LabelEncoder

lab=LabelEncoder()
train_test["YearBuilt"] = lab.fit_transform(train_test["YearBuilt"])
train_test["YearRemodAdd"] = lab.fit_transform(train_test["YearRemodAdd"])
train_test["GarageYrBlt"] = lab.fit_transform(train_test["GarageYrBlt"])

# %%
# 采集一下标签，确定一下每个数据需要用什么去编码
#miss1 = pd.DataFrame(train_test.columns)
#miss1.to_csv("D:\CS\miss.csv", encoding='utf-8', index=False)

# %%
# dummies_loc = ["MSSubClass", "MSZoning", "Street", "Alley", "LotShape", "LandContour", "Utilities", "LotConfig", "LandSlope", "Neighborhood", "Condition1",
#              "Condition2", "BldgType", "HouseStyle", "RoofStyle", "RoofMatl", "Exterior1st", "Exterior2nd", "MasVnrType", "ExterOual", "ExterCond", "Foundation",
#              "BsmtQual", "BsmtCond", "BsmtExposure", "BsmtFinType1", "BsmtFinType2", "Heating", "HeatingQC", "CentralAir", "Electrical", "LowQualFinSF", "BsmtFullBath", 
#              "BsmtHalfBath", ""]

train_test.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities',
#        ...
#        'oHeating', 'oHeatingQC', 'oKitchenQual', 'oFunctional', 'oFireplaceQu',
#        'oGarageType', 'oGarageFinish', 'oPavedDrive', 'oSaleType',
#        'oSaleCondition'],
#       dtype='object', length=102)

# %%
# 切分数据集
#train_test.drop(['Id'],axis=1,inplace=True)

from scipy.stats import skew

X_numeric=train_test.select_dtypes(exclude=["object"])
#X_numeric=X.select_dtypes(exclude=["object"])
#skewness = X_numeric.apply(lambda x: skew(x))
#skewness_features = skewness[abs(skewness) >= self.skew].index
#X[skewness_features] = np.log1p(X[skewness_features])

skewness = X_numeric.apply(lambda x: skew(x))
#skewness
skewness_features = skewness[abs(skewness) >= 1].index
#x_index =  X_numeric.columns
#X_numeric[x_index]
#skewness_features

train_test[skewness_features] = np.log1p(X_numeric[skewness_features])
train_test.head(5)
# Out:
#    Id MSSubClass MSZoning  LotFrontage   LotArea Street Alley LotShape  \
# 0   1         60       RL     4.189655  9.042040   Pave  None      Reg
# 1   2         20       RL     4.394449  9.169623   Pave  None      Reg
# 2   3         60       RL     4.234107  9.328212   Pave  None      IR1
# 3   4         70       RL     4.110874  9.164401   Pave  None      IR1
# 4   5         60       RL     4.442651  9.565284   Pave  None      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle OverallQual OverallCond  YearBuilt  \
# ...

# %%
train_test.drop(['Id'],axis=1,inplace=True)
xy = pd.get_dummies(train_test)
#        skewness = X_numeric.apply(lambda x: skew(x))
#        skewness_features = skewness[abs(skewness) >= self.skew].index
#        X[skewness_features] = np.log1p(X[skewness_features])
#       X = pd.get_dummies(X)

# %%
#train_test.head(5)
#train_test.info(verbose=True)
#train_test.columns

# %%
xy.info()
#xy.columns
#xy.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2919 entries, 0 to 2918
# Columns: 431 entries, LotFrontage to SaleCondition_Partial
# dtypes: float64(26), int64(19), uint8(386)
# memory usage: 2.1 MB

# %%
train_x = xy[:1460]
test_x = xy[1460:]
train_y = train["SalePrice"]

# %%
# 线性模型需要用标准化的数据建模

from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
scaler.fit(train_x)
train_x_sd = scaler.transform(train_x)
test_x_sd = scaler.transform(test_x)
y_log = np.log(train.SalePrice)

# %% [markdown]
# # 特征组合

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import SVR, LinearSVR
from sklearn.linear_model import ElasticNet, SGDRegressor, BayesianRidge
from sklearn.kernel_ridge import KernelRidge
from xgboost import XGBRegressor

# %%
lasso=Lasso(alpha=0.001)
lasso.fit(train_x_sd,y_log)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
FI_lasso = pd.DataFrame({"Feature Importance":lasso.coef_}, index=xy.columns)
FI_lasso[FI_lasso["Feature Importance"]!=0].sort_values("Feature Importance").plot(kind="barh",figsize=(15,25))
plt.xticks(rotation=90)
# Out:
# (array([-0.2 , -0.15, -0.1 , -0.05,  0.  ,  0.05,  0.1 ,  0.15,  0.2 ]),
#  <a list of 9 Text xticklabel objects>)

# %%
col=["OverallQual","FullBath"]
train_test[col]=train_test[col].astype(float)

train_test["TotalHouse"] = train_test["TotalBsmtSF"] + train_test["1stFlrSF"] + train_test["2ndFlrSF"]
train_test["TotalArea"] = train_test["TotalBsmtSF"] + train_test["1stFlrSF"] + train_test["2ndFlrSF"] + train_test["GarageArea"] 
train_test["+_TotalHouse_OverallQual"] = train_test["TotalHouse"] * train_test["OverallQual"]
train_test["+_GrLivArea_OverallQual"] = train_test["GrLivArea"] * train_test["OverallQual"]
train_test["+_oMSZoning_TotalHouse"] = train_test["oMSZoning"] * train_test["TotalHouse"]
train_test["+_oMSZoning_OverallQual"] = train_test["oMSZoning"] + train_test["OverallQual"]
train_test["+_oMSZoning_YearBuilt"] = train_test["oMSZoning"] + train_test["YearBuilt"]
train_test["+_oNeighborhood_TotalHouse"] = train_test["oNeighborhood"] * train_test["TotalHouse"]
train_test["+_oNeighborhood_OverallQual"] = train_test["oNeighborhood"] + train_test["OverallQual"]
train_test["+_oNeighborhood_YearBuilt"] = train_test["oNeighborhood"] + train_test["YearBuilt"]
train_test["+_BsmtFinSF1_OverallQual"] = train_test["BsmtFinSF1"] * train_test["OverallQual"]
            
train_test["-_oFunctional_TotalHouse"] = train_test["oFunctional"] * train_test["TotalHouse"]
train_test["-_oFunctional_OverallQual"] = train_test["oFunctional"] + train_test["OverallQual"]
train_test["-_LotArea_OverallQual"] = train_test["LotArea"] * train_test["OverallQual"]
train_test["-_TotalHouse_LotArea"] = train_test["TotalHouse"] + train_test["LotArea"]
train_test["-_oCondition1_TotalHouse"] = train_test["oCondition1"] * train_test["TotalHouse"]
train_test["-_oCondition1_OverallQual"] = train_test["oCondition1"] + train_test["OverallQual"]
            
           
train_test["Bsmt"] = train_test["BsmtFinSF1"] + train_test["BsmtFinSF2"] + train_test["BsmtUnfSF"]
train_test["Rooms"] = train_test["FullBath"]+train_test["TotRmsAbvGrd"]
train_test["PorchArea"] = train_test["OpenPorchSF"]+train_test["EnclosedPorch"]+train_test["3SsnPorch"]+train_test["ScreenPorch"]
train_test["TotalPlace"] = train_test["TotalBsmtSF"] + train_test["1stFlrSF"] + train_test["2ndFlrSF"] +train_test["GarageArea"] + train_test["OpenPorchSF"]+train_test["EnclosedPorch"]+train_test["3SsnPorch"]+train_test["ScreenPorch"]

# %%
#train_test.info(verbose=True)

col=["OverallQual","FullBath"]
train_test[col]=train_test[col].astype(str)


xy1 = pd.get_dummies(train_test)

train_x1 = xy1[:1460]
test_x1 = xy1[1460:]
train_y = train["SalePrice"]

from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
scaler.fit(train_x1)
train_x_sd1 = scaler.transform(train_x1)
test_x_sd1 = scaler.transform(test_x1)
y_log = np.log(train.SalePrice)

# %%
xy1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2919 entries, 0 to 2918
# Columns: 452 entries, LotFrontage to SaleCondition_Partial
# dtypes: float64(45), int64(21), uint8(386)
# memory usage: 2.5 MB

# %%
#from sklearn.decomposition import PCA, KernelPCA

#pca = PCA(n_components=431)
#train_x_sd1=pca.fit_transform(train_x_sd1)
#test_x_sd1 = pca.transform(test_x_sd1)

#train_x_sd1.shape, test_x_sd1.shape

# %% [markdown]
# # 建模

# %%
def rmse_cv(model,X,y):
    rmse = np.sqrt(-cross_val_score(model, X, y, scoring="neg_mean_squared_error", cv=5))
    return rmse

# %%
models = [LinearRegression(),Ridge(),Lasso(alpha=0.01,max_iter=10000),RandomForestRegressor(),GradientBoostingRegressor(),SVR(),LinearSVR(),
          ElasticNet(alpha=0.001,max_iter=10000),SGDRegressor(max_iter=1000,tol=1e-3),BayesianRidge(),KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5),
          ExtraTreesRegressor(),XGBRegressor()]

# %%
names = ["LR", "Ridge", "Lasso", "RF", "GBR", "SVR", "LinSVR", "Ela","SGD","Bay","Ker","Extra","Xgb"]
for name, model in zip(names, models):
    score = rmse_cv(model, train_x_sd1,y_log)
    print("{}: {:.6f}, {:.4f}".format(name,score.mean(),score.std())) # format为格式化，使输出按照指定样式排列
# Out:
# LR: 806778615.016832, 495378052.8655
# Ridge: 0.134937, 0.0159
# Lasso: 0.142914, 0.0126
# RF: 0.144964, 0.0080
# GBR: 0.129833, 0.0076
# SVR: 0.125243, 0.0125
# LinSVR: 0.147028, 0.0170
# Ela: 0.123263, 0.0137
# SGD: 0.330672, 0.0200
# Bay: 0.126520, 0.0137
# Ker: 0.124296, 0.0121
# Extra: 0.145737, 0.0115
# Xgb: 0.134616, 0.0059

# %%
y_log.head(10)
# Out:
# 0    12.247694
# 1    12.109011
# 2    12.317167
# 3    11.849398
# 4    12.429216
# 5    11.870600
# 6    12.634603
# 7    12.206073
# 8    11.774520
# 9    11.678440
# Name: SalePrice, dtype: float64

# %% [markdown]
# # 调参

# %%
class grid():
    def __init__(self,model):
        self.model = model
    
    def grid_get(self,X,y,param_grid):
        grid_search = GridSearchCV(self.model,param_grid,cv=5, scoring="neg_mean_squared_error",return_train_score=True)
        grid_search.fit(X,y)
        print(grid_search.best_params_, np.sqrt(-grid_search.best_score_))
        grid_search.cv_results_['mean_test_score'] = np.sqrt(-grid_search.cv_results_['mean_test_score'])
        print(pd.DataFrame(grid_search.cv_results_)[['params','mean_test_score','std_test_score']])

# %%
grid(Ridge()).grid_get(train_x_sd1,y_log,{'alpha':[33,34,35]})
# Out:
# {'alpha': 34} 0.12619606465819702
#           params  mean_test_score  std_test_score
# 0  {'alpha': 33}         0.126196        0.003320
# 1  {'alpha': 34}         0.126196        0.003317
# 2  {'alpha': 35}         0.126198        0.003315

# %%
grid(ElasticNet()).grid_get(train_x_sd1,y_log,{'alpha':[0.0006,0.0004,0.0005],'l1_ratio':[1.1,1.3,1.2],'max_iter':[10000]})
# Out:
# {'alpha': 0.0005, 'l1_ratio': 1.2, 'max_iter': 10000} 0.12378453628662842
#                                               params  mean_test_score  \
# 0  {'alpha': 0.0006, 'l1_ratio': 1.1, 'max_iter':...         0.123973
# 1  {'alpha': 0.0006, 'l1_ratio': 1.3, 'max_iter':...         0.124582
# 2  {'alpha': 0.0006, 'l1_ratio': 1.2, 'max_iter':...         0.124249
# 3  {'alpha': 0.0004, 'l1_ratio': 1.1, 'max_iter':...         0.124025
# 4  {'alpha': 0.0004, 'l1_ratio': 1.3, 'max_iter':...         0.123851
# 5  {'alpha': 0.0004, 'l1_ratio': 1.2, 'max_iter':...         0.123920
# 6  {'alpha': 0.0005, 'l1_ratio': 1.1, 'max_iter':...         0.123785
# 7  {'alpha': 0.0005, 'l1_ratio': 1.3, 'max_iter':...         0.123889
# 8  {'alpha': 0.0005, 'l1_ratio': 1.2, 'max_iter':...         0.123785
#
#    std_test_score
# 0        0.003435
# 1        0.003356
# 2        0.003399
# 3        0.003660
# 4        0.003624
# 5        0.003641
# 6        0.003533
# 7        0.003493
# ...

# %%
#grid(RandomForestRegressor()).grid_get(train_x_sd,y_log,{'n_estimators' : [160,170,180], 'n_jobs': [-1], 'oob_score':[False]})

# %%
grid(SVR()).grid_get(train_x_sd1,y_log,{'C':[2,1,3],'kernel':["rbf"],"gamma":[0.002,0.003],"epsilon":[0.03,0.02]})
# Out:
# {'C': 3, 'epsilon': 0.03, 'gamma': 0.002, 'kernel': 'rbf'} 0.12139198853040586
#                                                params  mean_test_score  \
# 0   {'C': 2, 'epsilon': 0.03, 'gamma': 0.002, 'ker...         0.121514
# 1   {'C': 2, 'epsilon': 0.03, 'gamma': 0.003, 'ker...         0.121407
# 2   {'C': 2, 'epsilon': 0.02, 'gamma': 0.002, 'ker...         0.121812
# 3   {'C': 2, 'epsilon': 0.02, 'gamma': 0.003, 'ker...         0.121588
# 4   {'C': 1, 'epsilon': 0.03, 'gamma': 0.002, 'ker...         0.122666
# 5   {'C': 1, 'epsilon': 0.03, 'gamma': 0.003, 'ker...         0.121944
# 6   {'C': 1, 'epsilon': 0.02, 'gamma': 0.002, 'ker...         0.122584
# 7   {'C': 1, 'epsilon': 0.02, 'gamma': 0.003, 'ker...         0.122029
# 8   {'C': 3, 'epsilon': 0.03, 'gamma': 0.002, 'ker...         0.121392
# 9   {'C': 3, 'epsilon': 0.03, 'gamma': 0.003, 'ker...         0.121909
# 10  {'C': 3, 'epsilon': 0.02, 'gamma': 0.002, 'ker...         0.121741
# ...

# %%
grid(GradientBoostingRegressor()).grid_get(train_x_sd1,y_log,{'n_estimators' : [170,180,190], 'learning_rate': [0.1], 'alpha':[0.5]})
# Out:
# {'alpha': 0.5, 'learning_rate': 0.1, 'n_estimators': 180} 0.12805803379953437
#                                               params  mean_test_score  \
# 0  {'alpha': 0.5, 'learning_rate': 0.1, 'n_estima...         0.128292
# 1  {'alpha': 0.5, 'learning_rate': 0.1, 'n_estima...         0.128058
# 2  {'alpha': 0.5, 'learning_rate': 0.1, 'n_estima...         0.128221
#
#    std_test_score
# 0        0.002077
# 1        0.002056
# 2        0.002178

# %%
param_grid ={'alpha':[0.13,0.12,0.11], 'kernel':["polynomial"], 'degree':[3],'coef0':[0.9,0.8,1.0]}
grid(KernelRidge()).grid_get(train_x_sd1,y_log,param_grid)
# Out:
# {'alpha': 0.12, 'coef0': 1.0, 'degree': 3, 'kernel': 'polynomial'} 0.1212915308277238
#                                               params  mean_test_score  \
# 0  {'alpha': 0.13, 'coef0': 0.9, 'degree': 3, 'ke...         0.121485
# 1  {'alpha': 0.13, 'coef0': 0.8, 'degree': 3, 'ke...         0.122025
# 2  {'alpha': 0.13, 'coef0': 1.0, 'degree': 3, 'ke...         0.121297
# 3  {'alpha': 0.12, 'coef0': 0.9, 'degree': 3, 'ke...         0.121414
# 4  {'alpha': 0.12, 'coef0': 0.8, 'degree': 3, 'ke...         0.121860
# 5  {'alpha': 0.12, 'coef0': 1.0, 'degree': 3, 'ke...         0.121292
# 6  {'alpha': 0.11, 'coef0': 0.9, 'degree': 3, 'ke...         0.121366
# 7  {'alpha': 0.11, 'coef0': 0.8, 'degree': 3, 'ke...         0.121715
# 8  {'alpha': 0.11, 'coef0': 1.0, 'degree': 3, 'ke...         0.121311
#
#    std_test_score
# 0        0.002397
# 1        0.002377
# 2        0.002426
# 3        0.002394
# 4        0.002371
# 5        0.002425
# 6        0.002392
# 7        0.002365
# ...

# %%
param={'n_estimators': [450],'learning_rate': [0.1, 0.08, 0.09]}#
grid(XGBRegressor()).grid_get(train_x_sd1,y_log,param)
# Out:
# {'learning_rate': 0.09, 'n_estimators': 450} 0.12699097521916433
#                                          params  mean_test_score  \
# 0   {'learning_rate': 0.1, 'n_estimators': 450}         0.129429
# 1  {'learning_rate': 0.08, 'n_estimators': 450}         0.127234
# 2  {'learning_rate': 0.09, 'n_estimators': 450}         0.126991
#
#    std_test_score
# 0        0.001539
# 1        0.001700
# 2        0.001700

# %%
ridge = Ridge(alpha=34)
ela = ElasticNet(alpha=0.0005,l1_ratio=1.2,max_iter=10000)
svr = SVR(C=3, epsilon=0.03, gamma=0.002, kernel='rbf')
bay = BayesianRidge()
gbr = GradientBoostingRegressor(alpha = 0.5, learning_rate = 0.1, n_estimators = 180)
ker = KernelRidge(alpha=0.12, coef0=1.0, degree=3, kernel='polynomial')
xgbt = XGBRegressor(learning_rate=0.09, n_estimators=450)

# %% [markdown]
# # 集成

# %%
class AverageWeight(BaseEstimator, RegressorMixin):
    def __init__(self,mod,weight):
        self.mod = mod
        self.weight = weight
        
    def fit(self,X,y):
        self.models_ = [clone(x) for x in self.mod]
        for model in self.models_:
            model.fit(X,y)
        return self
    
    def predict(self,X):
        w = list()
        pred = np.array([model.predict(X) for model in self.models_])
        # for every data point, single model prediction times weight, then add them together
        for data in range(pred.shape[1]):
            single = [pred[model,data]*weight for model,weight in zip(range(pred.shape[0]),self.weight)]
            w.append(np.sum(single))
        return w

# %%
w1 = 0.1
w2 = 0.2
w3 = 0.25
w4 = 0.1
w5 = 0.05
w6 = 0.25
w7 = 0.05

# %%
weight_avg = AverageWeight(mod = [ridge,ela,svr,bay,gbr,ker,xgbt],weight=[w1,w2,w3,w4,w5,w6,w7])

# %%
rmse_cv(weight_avg,train_x_sd1,y_log),  rmse_cv(weight_avg,train_x_sd1,y_log).mean()
# Out:
# (array([0.1031327 , 0.13200443, 0.12028796, 0.10576748, 0.13369755]),
#  0.11897311807709288)

# %%
weight_avg2  = AverageWeight(mod = [svr,ker],weight=[0.5,0.5])
rmse_cv(weight_avg2,train_x_sd1,y_log),  rmse_cv(weight_avg2,train_x_sd1,y_log).mean()
# Out:
# (array([0.10334784, 0.13424685, 0.12140418, 0.10471237, 0.13305692]),
#  0.11935363323604622)

# %%
weight_avg.fit(train_x_sd1,y_log)
# Out:
# AverageWeight(mod=[Ridge(alpha=34, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001), ElasticNet(alpha=0.0005, copy_X=True, fit_intercept=True, l1_ratio=1.2,
#       max_iter=10000, normalize=False, positive=False, precompute=False,
#       random_state=N...,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)],
#        weight=[0.1, 0.2, 0.25, 0.1, 0.05, 0.25, 0.05])

# %%
pred = np.exp(weight_avg.predict(test_x_sd1))
result_vot=pd.DataFrame({'Id':test.Id, 'SalePrice':pred})
result_vot.to_csv("D:/CS/ML/Kaggle/HousePrices/v1.0/submission_vote1.1.csv",index=False)

# %%
class stacking(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self,mod,meta_model):
        self.mod = mod
        self.meta_model = meta_model
        self.kf = KFold(n_splits=7, random_state=42, shuffle=True)
        
    def fit(self,X,y):
        self.saved_model = [list() for i in self.mod]
        oof_train = np.zeros((X.shape[0], len(self.mod)))
        
        for i,model in enumerate(self.mod):
            for train_index, val_index in self.kf.split(X,y):
                renew_model = clone(model)
                renew_model.fit(X[train_index], y[train_index])
                self.saved_model[i].append(renew_model)
                oof_train[val_index,i] = renew_model.predict(X[val_index])
        
        self.meta_model.fit(oof_train,y)
        return self
    
    def predict(self,X):
        whole_test = np.column_stack([np.column_stack(model.predict(X) for model in single_model).mean(axis=1) 
                                      for single_model in self.saved_model]) 
        return self.meta_model.predict(whole_test)
 
    # get_oof的方法将第一层模型的特征矩阵提取出来，再和原始特征进行拼接.(使用过拟合)
    def get_oof(self,X,y,test_X):
        oof = np.zeros((X.shape[0],len(self.mod)))
        test_single = np.zeros((test_X.shape[0],5))
        test_mean = np.zeros((test_X.shape[0],len(self.mod)))
        for i,model in enumerate(self.mod):
            for j, (train_index,val_index) in enumerate(self.kf.split(X,y)):
                clone_model = clone(model)
                clone_model.fit(X[train_index],y[train_index])
                oof[val_index,i] = clone_model.predict(X[val_index])
                test_single[:,j] = clone_model.predict(test_X)
            test_mean[:,i] = test_single.mean(axis=1)
        return oof, test_mean

# %%
stack_model = stacking(mod=[ridge,ela,svr,bay,gbr,ker,xgbt],meta_model=svr)

# %%
from sklearn.preprocessing import Imputer
a = Imputer().fit_transform(train_x_sd1)
b = Imputer().fit_transform(y_log.values.reshape(-1,1)).ravel()

rmse_cv(stack_model,a,b).mean()
# Out:
# 0.11917835572045743

# %%
stack_model.fit(train_x_sd1,y_log)
# Out:
# stacking(meta_model=SVR(C=3, cache_size=200, coef0=0.0, degree=3, epsilon=0.03, gamma=0.002,
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False),
#      mod=[Ridge(alpha=34, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001), ElasticNet(alpha=0.0005, copy_X=True, fit_intercept=True, l1_ratio=1.2,
#       max_iter=10000, normalize=False, positive=False, precompute=False,
#       random_state=N...,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)])

# %%
pred = np.exp(stack_model.predict(test_x_sd1))

# %%
result=pd.DataFrame({'Id':test.Id, 'SalePrice':pred})
result.to_csv("D:/CS/ML/Kaggle/HousePrices/v1.0/submission_stacking1.1.csv",index=False)

# %%
# 使用ab效果不如不用

stack_model.fit(train_x_sd,b)
pred_ab = np.exp(stack_model.predict(test_x_sd))
result=pd.DataFrame({'Id':test.Id, 'SalePrice':pred})
result.to_csv("D:/CS/ML/Kaggle/HousePrices/v1.0/submission1.2.csv",index=False)
